# %%
import os     ## Allows operating system commands to be performed though Python
import sys    ## Allows you to exit a Python script for testing
import shutil ## Allows movement of files from one directory to another
import string ## Fancy string manipulations
import  glob  ## Global searching of strings as files
import pandas as pd

# %%
#create function for cleaning lines
clean = lambda dirty: ''.join(filter(string.printable.__contains__, dirty))

# %%
#set path to text files
pwd = ['C:\\Users\\akomandu\\PDF_Scrapes\\Georgia_Pacific_MSDS\\text']
os.chdir("".join(pwd))
pwd = os.getcwd()

# %%
#find all text files
files = glob.glob('*.txt')

# %%
#create lists for pertinent information in each text file
Product_Identifier = []
Chemical_Name = []
Manufacturer = []
CAS_Number = []
Percentage = []
Product_List = []
Product_Lister= []
Product_Umbrella = []

#iterate through each text file to clean lines and append relevant information to lists
for file in files:
    
    ifile = open(file)    
    for line in ifile:
        if line == '/n': continue
        cline = clean(line)
        cline = cline.lower()
        cline = cline.replace(',','_')
        cline = cline.replace(';','_')
        cline = cline.strip()

        tline = "".join(cline.split())
        tline = "".join(cline.split())
        cline = cline.split("  ")
        cline = [x.strip() for x in cline if x != ""]

        if 'product identifier' in cline:
            product = cline[-1]
    #        print(product)

        elif 'product list' in cline:
            list10 = []
            list10.append(cline[-1])
            for line in ifile:
                zline = clean(line)
                zline = zline.lower()
                zline = zline.replace(',','_')
                zline = zline.replace(';','_')
                zline = zline.strip()
                zline  = zline.split("  ")
                zline = [x.strip() for x in zline if x != ""]

                list10.append(zline)
                list20 = [x for x in list10 if x!= []]
                list20 = list20[0:-1]
                for i in range(len(list20)):
                    if type(list20[i]) is list:
                        list20[i] = list20[i][0]
                    else:
                        list20[i] = list20[i]                
                if 'other means of identification' in str(line).lower():
                    break
                    
                for i in list20:
                    Product_Umbrella.append(product)
                    try:
                        Product_Lister.append(i)
                    except IndexError:
                        Product_Lister.append(' ')

        elif 'company name' in cline:
            company = cline[-1]
        
        elif 'cas number' in cline:
            list1 = []
            for line in ifile:
                dline = clean(line)
                dline = dline.lower()
                dline = dline.replace(',','_')
                dline = dline.replace(';','_')
                dline = dline.strip()
                dline  = dline.split("  ")
                dline = [x.strip() for x in dline if x != ""]
            
            
            
            

                list1.append(dline)
    #            list2 = [x for x in list1 if x != []]
                list2 = [x for x in list1 if x != []]
    #            list2 = list2[0:-1]

                for i in list2:
                    try:
                        Product_Identifier.append(product)
                    except IndexError:
                        Product_Identifier.append(' ')
                    try:
                        Product_List.append(list20)
                    except IndexError:
                        Product_List.append(' ')
                    try:
                        Manufacturer.append(company)
                    except IndexError:
                        Manufacturer.append(' ')
                    try:
                        Chemical_Name.append(i[0])
                    except IndexError:
                        Chemical_Name.append(' ')
                    try:
                        CAS_Number.append(i[1])
                    except IndexError:
                        CAS_Number.append(' ')
                    try :
                        Percentage.append(i[2])
                    except IndexError:
                        Percentage.append(' ')
                        #Product_Identifier.append(null)
                        #Manufacturer.append(null)
                        #Chemical_Name.append(null)
                        #CAS_Number.append(null)
                        #Percentage.append(null)
                if 'trade secret' in str(line).lower():
                    break
                elif 'trade secrets' in str(line).lower():
                    break
                elif 'other components' in str(line).lower():
                    break
                elif 'first-aid' in str(line).lower():
                    break

# %%
#create dataframe to display scraped data in the lists
Scraped_Data = pd.DataFrame({'Product_Identifier': Product_Identifier, 'Chemical_Name': Chemical_Name, 'CAS_Number': CAS_Number, 'Percentage': Percentage, 'Manufacturer': Manufacturer, 'Product_List': Product_List})

# %%
#stack information from previous dataframe into final dataframe to display each product in its own row
import numpy as np
Scraped_Data.loc[:, 'Product_List'] = Scraped_Data.Product_List.apply(np.atleast_1d)
all_products = np.hstack(Scraped_Data.Product_List)
all_names = np.hstack([[n]*len(l) for n, l in Scraped_Data[['Product_Identifier', 'Product_List']].values])
all_CAS = np.hstack([[n]*len(l) for n, l in Scraped_Data[['CAS_Number', 'Product_List']].values])
all_chemicals = np.hstack([[n]*len(l) for n, l in Scraped_Data[['Chemical_Name', 'Product_List']].values])
all_manufacturers = np.hstack([[n]*len(l) for n, l in Scraped_Data[['Manufacturer', 'Product_List']].values])
all_percentages = np.hstack([[n]*len(l) for n, l in Scraped_Data[['Percentage', 'Product_List']].values])
dfOut = pd.DataFrame({'Product_Identifier': all_names, 'Product_List': all_products, 'CAS_Number': all_CAS, 'Chemical_Name': all_chemicals, 'Percentage': all_percentages, 'Manufacturer': all_manufacturers})
Final = dfOut.drop_duplicates(keep='first')
Final
# Out:
#                       CAS_Number  \
# 0                     10101-41-4
# 1                     10101-41-4
# 2                     10101-41-4
# 3                     10101-41-4
# 4                     10101-41-4
# 5                     10101-41-4
# 18                    14808-60-7
# 19                    14808-60-7
# 20                    14808-60-7
# 21                    14808-60-7
# 22                    14808-60-7
# 23                    14808-60-7
# 48
# 49
# 50
# 51
# 52
# 53
# 54                     7778-18-9
# 55                     7778-18-9
# 56                     7778-18-9
# 57                     7778-18-9
# 58                     7778-18-9
# 59                     7778-18-9
# 72                     1318-00-9
# 73                     1318-00-9
# 74                     1318-00-9
# 75                     1318-00-9
# 76                     1318-00-9
# 77                     1318-00-9
# ...                          ...
# 448971
# 449004  21 cfr part 333.410 (a).
# 449005  21 cfr part 333.410 (a).
# 449006  21 cfr part 333.410 (a).
# 449007  21 cfr part 333.410 (a).
# 449048
# 449049
# 449050
# 449051
# 449052                 7732-18-5
# 449055                26183-52-8
# 449060                68603-38-3
# 449067
# 449076
# 449087                   56-81-5
# 449100                68606-94-0
# 449115
# 449132                    5 - 10
# 449133                 7732-18-5
# 449136                 9009-54-5
# 449141                61790-12-3
# 449148                69011-36-5
# 449157                68603-38-3
# 449168
# 449181
# 449196                       1-3
# 449197                   56-81-5
# 449200                68585-34-2
# 449205                61789-40-0
# 449212                  60 - 100
#
#                                             Chemical_Name  \
# 0                                gypsum (calcium sulfate)
# 1                                gypsum (calcium sulfate)
# 2                                gypsum (calcium sulfate)
# 3                                gypsum (calcium sulfate)
# 4                                gypsum (calcium sulfate)
# 5                                gypsum (calcium sulfate)
# 18                            crystalline silica (quartz)
# 19                            crystalline silica (quartz)
# 20                            crystalline silica (quartz)
# 21                            crystalline silica (quartz)
# 22                            crystalline silica (quartz)
# 23                            crystalline silica (quartz)
# 48      the specific chemical identity and/or percenta...
# 49      the specific chemical identity and/or percenta...
# 50      the specific chemical identity and/or percenta...
# 51      the specific chemical identity and/or percenta...
# 52      the specific chemical identity and/or percenta...
# 53      the specific chemical identity and/or percenta...
# 54                               gypsum (calcium sulfate)
# 55                               gypsum (calcium sulfate)
# 56                               gypsum (calcium sulfate)
# 57                               gypsum (calcium sulfate)
# 58                               gypsum (calcium sulfate)
# 59                               gypsum (calcium sulfate)
# 72                                            vermiculite
# 73                                            vermiculite
# 74                                            vermiculite
# 75                                            vermiculite
# 76                                            vermiculite
# 77                                            vermiculite
# ...                                                   ...
# 448971  meets alcohol requirements stated in fda tenta...
# 449004                           antiseptic drug products
# 449005                           antiseptic drug products
# 449006                           antiseptic drug products
# 449007                           antiseptic drug products
# 449048                              4. first-aid measures
# 449049                              4. first-aid measures
# 449050                              4. first-aid measures
# 449051                              4. first-aid measures
# 449052                                              water
# 449055                                           deceth-6
# 449060                                 amides_ c16-18 and
# 449067                                   c18-unsaturated_
# 449076                              n_n-bis(hydroxyethyl)
# 449087                                           glycerin
# 449100                               oils_ orange_ sweet_
# 449115                                       terpene-free
# 449132           other components below reportable levels
# 449133                                              water
# 449136                                 polyurethane beads
# 449141                                      tall oil acid
# 449148                                        trideceth-6
# 449157                                 amides_ c16-18 and
# 449168                                   c18-unsaturated_
# 449181                              n_n-bis(hydroxyethyl)
# 449196           other components below reportable levels
# 449197                                           glycerin
# 449200                             sodium laureth sulfate
# 449205                             cocamidopropyl betaine
# 449212           other components below reportable levels
#
#                                 Manufacturer Percentage  \
# 0                 georgia-pacific gypsum llc        100
# 1                 georgia-pacific gypsum llc        100
# 2                 georgia-pacific gypsum llc        100
# 3                 georgia-pacific gypsum llc        100
# 4                 georgia-pacific gypsum llc        100
# 5                 georgia-pacific gypsum llc        100
# 18                georgia-pacific gypsum llc        0-1
# 19                georgia-pacific gypsum llc        0-1
# 20                georgia-pacific gypsum llc        0-1
# 21                georgia-pacific gypsum llc        0-1
# 22                georgia-pacific gypsum llc        0-1
# 23                georgia-pacific gypsum llc        0-1
# 48                georgia-pacific gypsum llc
# 49                georgia-pacific gypsum llc
# 50                georgia-pacific gypsum llc
# 51                georgia-pacific gypsum llc
# 52                georgia-pacific gypsum llc
# 53                georgia-pacific gypsum llc
# 54                georgia-pacific gypsum llc         95
# 55                georgia-pacific gypsum llc         95
# 56                georgia-pacific gypsum llc         95
# 57                georgia-pacific gypsum llc         95
# 58                georgia-pacific gypsum llc         95
# 59                georgia-pacific gypsum llc         95
# 72                georgia-pacific gypsum llc        0-5
# 73                georgia-pacific gypsum llc        0-5
# 74                georgia-pacific gypsum llc        0-5
# 75                georgia-pacific gypsum llc        0-5
# 76                georgia-pacific gypsum llc        0-5
# 77                georgia-pacific gypsum llc        0-5
# ...                                      ...        ...
# 448971                     manufactured for:
# 449004                     manufactured for:
# 449005                     manufactured for:
# 449006                     manufactured for:
# 449007                     manufactured for:
# 449048                     manufactured for:
# 449049                     manufactured for:
# 449050                     manufactured for:
# 449051                     manufactured for:
# 449052  georgia-pacific consumer products lp   60 - 100
# 449055  georgia-pacific consumer products lp     5 - 10
# 449060  georgia-pacific consumer products lp        1-5
# 449067  georgia-pacific consumer products lp
# 449076  georgia-pacific consumer products lp
# 449087  georgia-pacific consumer products lp        1-5
# 449100  georgia-pacific consumer products lp    0.1 - 1
# 449115  georgia-pacific consumer products lp
# 449132  georgia-pacific consumer products lp
# 449133  georgia-pacific consumer products lp    70 - 80
# 449136  georgia-pacific consumer products lp     5 - 10
# 449141  georgia-pacific consumer products lp     5 - 10
# 449148  georgia-pacific consumer products lp     5 - 10
# 449157  georgia-pacific consumer products lp        1-3
# 449168  georgia-pacific consumer products lp
# 449181  georgia-pacific consumer products lp
# 449196  georgia-pacific consumer products lp
# 449197                     manufactured for:        1-5
# 449200                     manufactured for:        1-5
# 449205                     manufactured for:    0.1 - 1
# 449212                     manufactured for:
#
#                                        Product_Identifier  \
# 0                              uncalcined gypsum products
# 1                              uncalcined gypsum products
# 2                              uncalcined gypsum products
# 3                              uncalcined gypsum products
# 4                              uncalcined gypsum products
# 5                              uncalcined gypsum products
# 18                             uncalcined gypsum products
# 19                             uncalcined gypsum products
# 20                             uncalcined gypsum products
# 21                             uncalcined gypsum products
# 22                             uncalcined gypsum products
# 23                             uncalcined gypsum products
# 48                             uncalcined gypsum products
# 49                             uncalcined gypsum products
# 50                             uncalcined gypsum products
# 51                             uncalcined gypsum products
# 52                             uncalcined gypsum products
# 53                             uncalcined gypsum products
# 54                                 agricultural gypsum ii
# 55                                 agricultural gypsum ii
# 56                                 agricultural gypsum ii
# 57                                 agricultural gypsum ii
# 58                                 agricultural gypsum ii
# 59                                 agricultural gypsum ii
# 72                                 agricultural gypsum ii
# 73                                 agricultural gypsum ii
# 74                                 agricultural gypsum ii
# 75                                 agricultural gypsum ii
# 76                                 agricultural gypsum ii
# 77                                 agricultural gypsum ii
# ...                                                   ...
# 448971    enmotion high frequency use foam hand sanitizer
# 449004    enmotion high frequency use foam hand sanitizer
# 449005    enmotion high frequency use foam hand sanitizer
# 449006    enmotion high frequency use foam hand sanitizer
# 449007    enmotion high frequency use foam hand sanitizer
# 449048    enmotion high frequency use foam hand sanitizer
# 449049    enmotion high frequency use foam hand sanitizer
# 449050    enmotion high frequency use foam hand sanitizer
# 449051    enmotion high frequency use foam hand sanitizer
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449132  georgia-pacific heavy duty industrial hand cle...
# 449133            georgia-pacific industrial hand cleaner
# 449136            georgia-pacific industrial hand cleaner
# 449141            georgia-pacific industrial hand cleaner
# 449148            georgia-pacific industrial hand cleaner
# 449157            georgia-pacific industrial hand cleaner
# 449168            georgia-pacific industrial hand cleaner
# 449181            georgia-pacific industrial hand cleaner
# 449196            georgia-pacific industrial hand cleaner
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
# 449212  enmotion general purpose foam soap_ dye-free f...
#
#                                              Product_List
# 0                                             gypsum rock
# 1                                           ground gypsum
# 2                                         granular gypsum
# 3                                              terra alba
# 4                      bumper harvest agricultural gypsum
# 5                                             landplaster
# 18                                            gypsum rock
# 19                                          ground gypsum
# 20                                        granular gypsum
# 21                                             terra alba
# 22                     bumper harvest agricultural gypsum
# 23                                            landplaster
# 48                                            gypsum rock
# 49                                          ground gypsum
# 50                                        granular gypsum
# 51                                             terra alba
# 52                     bumper harvest agricultural gypsum
# 53                                            landplaster
# 54                                            gypsum rock
# 55                                          ground gypsum
# 56                                        granular gypsum
# 57                                             terra alba
# 58                     bumper harvest agricultural gypsum
# 59                                            landplaster
# 72                                            gypsum rock
# 73                                          ground gypsum
# 74                                        granular gypsum
# 75                                             terra alba
# 76                     bumper harvest agricultural gypsum
# 77                                            landplaster
# ...                                                   ...
# 448971  enmotion high frequency foam hand sanitizer wi...
# 449004  enmotion high frequency use foam hand sanitize...
# 449005  enmotion high frequency use foam hand sanitize...
# 449006                                             gp6173
# 449007  enmotion high frequency foam hand sanitizer wi...
# 449048  enmotion high frequency use foam hand sanitize...
# 449049  enmotion high frequency use foam hand sanitize...
# 449050                                             gp6173
# 449051  enmotion high frequency foam hand sanitizer wi...
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449132  georgia-pacific heavy duty industrial hand cle...
# 449133  georgia-pacific industrial hand cleaner sku-44623
# 449136  georgia-pacific industrial hand cleaner sku-44623
# 449141  georgia-pacific industrial hand cleaner sku-44623
# 449148  georgia-pacific industrial hand cleaner sku-44623
# 449157  georgia-pacific industrial hand cleaner sku-44623
# 449168  georgia-pacific industrial hand cleaner sku-44623
# 449181  georgia-pacific industrial hand cleaner sku-44623
# 449196  georgia-pacific industrial hand cleaner sku-44623
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
# 449212  enmotion general purpose foam soap_ dye-free f...
#
# [6764 rows x 6 columns]

# %% [markdown]
# ## Filter through dataframe to remove extraneous information (e.g. remove words and sentences that were accidentally included in the dataframe)

# %%
Final['Chemical_Name'].value_counts()
filters = [
'other components below reportable levels',
'the specific chemical identity and/or percentage of composition has been withheld as a trade secret.',
'chemical name',
'4. first-aid measures',
'composition comments',
    'hmis ratings',
    'international inventories',
    'safe drinking water act',
    'version #',
    'country(s) or region',
    'us. california proposition 65 '
]

# %%
first_pass = Final[Final['Chemical_Name'].map(lambda x: x not in filters)]
first_pass
# Out:
#                       CAS_Number  \
# 0                     10101-41-4
# 1                     10101-41-4
# 2                     10101-41-4
# 3                     10101-41-4
# 4                     10101-41-4
# 5                     10101-41-4
# 18                    14808-60-7
# 19                    14808-60-7
# 20                    14808-60-7
# 21                    14808-60-7
# 22                    14808-60-7
# 23                    14808-60-7
# 54                     7778-18-9
# 55                     7778-18-9
# 56                     7778-18-9
# 57                     7778-18-9
# 58                     7778-18-9
# 59                     7778-18-9
# 72                     1318-00-9
# 73                     1318-00-9
# 74                     1318-00-9
# 75                     1318-00-9
# 76                     1318-00-9
# 77                     1318-00-9
# 102                   65997-17-3
# 103                   65997-17-3
# 104                   65997-17-3
# 105                   65997-17-3
# 106                   65997-17-3
# 107                   65997-17-3
# ...                          ...
# 448920                   67-63-0
# 448921                   67-63-0
# 448922                   67-63-0
# 448923                   67-63-0
# 448968
# 448969
# 448970
# 448971
# 449004  21 cfr part 333.410 (a).
# 449005  21 cfr part 333.410 (a).
# 449006  21 cfr part 333.410 (a).
# 449007  21 cfr part 333.410 (a).
# 449052                 7732-18-5
# 449055                26183-52-8
# 449060                68603-38-3
# 449067
# 449076
# 449087                   56-81-5
# 449100                68606-94-0
# 449115
# 449133                 7732-18-5
# 449136                 9009-54-5
# 449141                61790-12-3
# 449148                69011-36-5
# 449157                68603-38-3
# 449168
# 449181
# 449197                   56-81-5
# 449200                68585-34-2
# 449205                61789-40-0
#
#                                             Chemical_Name  \
# 0                                gypsum (calcium sulfate)
# 1                                gypsum (calcium sulfate)
# 2                                gypsum (calcium sulfate)
# 3                                gypsum (calcium sulfate)
# 4                                gypsum (calcium sulfate)
# 5                                gypsum (calcium sulfate)
# 18                            crystalline silica (quartz)
# 19                            crystalline silica (quartz)
# 20                            crystalline silica (quartz)
# 21                            crystalline silica (quartz)
# 22                            crystalline silica (quartz)
# 23                            crystalline silica (quartz)
# 54                               gypsum (calcium sulfate)
# 55                               gypsum (calcium sulfate)
# 56                               gypsum (calcium sulfate)
# 57                               gypsum (calcium sulfate)
# 58                               gypsum (calcium sulfate)
# 59                               gypsum (calcium sulfate)
# 72                                            vermiculite
# 73                                            vermiculite
# 74                                            vermiculite
# 75                                            vermiculite
# 76                                            vermiculite
# 77                                            vermiculite
# 102                             continuous filament glass
# 103                             continuous filament glass
# 104                             continuous filament glass
# 105                             continuous filament glass
# 106                             continuous filament glass
# 107                             continuous filament glass
# ...                                                   ...
# 448920                                  isopropyl alcohol
# 448921                                  isopropyl alcohol
# 448922                                  isopropyl alcohol
# 448923                                  isopropyl alcohol
# 448968  meets alcohol requirements stated in fda tenta...
# 448969  meets alcohol requirements stated in fda tenta...
# 448970  meets alcohol requirements stated in fda tenta...
# 448971  meets alcohol requirements stated in fda tenta...
# 449004                           antiseptic drug products
# 449005                           antiseptic drug products
# 449006                           antiseptic drug products
# 449007                           antiseptic drug products
# 449052                                              water
# 449055                                           deceth-6
# 449060                                 amides_ c16-18 and
# 449067                                   c18-unsaturated_
# 449076                              n_n-bis(hydroxyethyl)
# 449087                                           glycerin
# 449100                               oils_ orange_ sweet_
# 449115                                       terpene-free
# 449133                                              water
# 449136                                 polyurethane beads
# 449141                                      tall oil acid
# 449148                                        trideceth-6
# 449157                                 amides_ c16-18 and
# 449168                                   c18-unsaturated_
# 449181                              n_n-bis(hydroxyethyl)
# 449197                                           glycerin
# 449200                             sodium laureth sulfate
# 449205                             cocamidopropyl betaine
#
#                                 Manufacturer Percentage  \
# 0                 georgia-pacific gypsum llc        100
# 1                 georgia-pacific gypsum llc        100
# 2                 georgia-pacific gypsum llc        100
# 3                 georgia-pacific gypsum llc        100
# 4                 georgia-pacific gypsum llc        100
# 5                 georgia-pacific gypsum llc        100
# 18                georgia-pacific gypsum llc        0-1
# 19                georgia-pacific gypsum llc        0-1
# 20                georgia-pacific gypsum llc        0-1
# 21                georgia-pacific gypsum llc        0-1
# 22                georgia-pacific gypsum llc        0-1
# 23                georgia-pacific gypsum llc        0-1
# 54                georgia-pacific gypsum llc         95
# 55                georgia-pacific gypsum llc         95
# 56                georgia-pacific gypsum llc         95
# 57                georgia-pacific gypsum llc         95
# 58                georgia-pacific gypsum llc         95
# 59                georgia-pacific gypsum llc         95
# 72                georgia-pacific gypsum llc        0-5
# 73                georgia-pacific gypsum llc        0-5
# 74                georgia-pacific gypsum llc        0-5
# 75                georgia-pacific gypsum llc        0-5
# 76                georgia-pacific gypsum llc        0-5
# 77                georgia-pacific gypsum llc        0-5
# 102               georgia-pacific gypsum llc        0-1
# 103               georgia-pacific gypsum llc        0-1
# 104               georgia-pacific gypsum llc        0-1
# 105               georgia-pacific gypsum llc        0-1
# 106               georgia-pacific gypsum llc        0-1
# 107               georgia-pacific gypsum llc        0-1
# ...                                      ...        ...
# 448920                     manufactured for:        1-5
# 448921                     manufactured for:        1-5
# 448922                     manufactured for:        1-5
# 448923                     manufactured for:        1-5
# 448968                     manufactured for:
# 448969                     manufactured for:
# 448970                     manufactured for:
# 448971                     manufactured for:
# 449004                     manufactured for:
# 449005                     manufactured for:
# 449006                     manufactured for:
# 449007                     manufactured for:
# 449052  georgia-pacific consumer products lp   60 - 100
# 449055  georgia-pacific consumer products lp     5 - 10
# 449060  georgia-pacific consumer products lp        1-5
# 449067  georgia-pacific consumer products lp
# 449076  georgia-pacific consumer products lp
# 449087  georgia-pacific consumer products lp        1-5
# 449100  georgia-pacific consumer products lp    0.1 - 1
# 449115  georgia-pacific consumer products lp
# 449133  georgia-pacific consumer products lp    70 - 80
# 449136  georgia-pacific consumer products lp     5 - 10
# 449141  georgia-pacific consumer products lp     5 - 10
# 449148  georgia-pacific consumer products lp     5 - 10
# 449157  georgia-pacific consumer products lp        1-3
# 449168  georgia-pacific consumer products lp
# 449181  georgia-pacific consumer products lp
# 449197                     manufactured for:        1-5
# 449200                     manufactured for:        1-5
# 449205                     manufactured for:    0.1 - 1
#
#                                        Product_Identifier  \
# 0                              uncalcined gypsum products
# 1                              uncalcined gypsum products
# 2                              uncalcined gypsum products
# 3                              uncalcined gypsum products
# 4                              uncalcined gypsum products
# 5                              uncalcined gypsum products
# 18                             uncalcined gypsum products
# 19                             uncalcined gypsum products
# 20                             uncalcined gypsum products
# 21                             uncalcined gypsum products
# 22                             uncalcined gypsum products
# 23                             uncalcined gypsum products
# 54                                 agricultural gypsum ii
# 55                                 agricultural gypsum ii
# 56                                 agricultural gypsum ii
# 57                                 agricultural gypsum ii
# 58                                 agricultural gypsum ii
# 59                                 agricultural gypsum ii
# 72                                 agricultural gypsum ii
# 73                                 agricultural gypsum ii
# 74                                 agricultural gypsum ii
# 75                                 agricultural gypsum ii
# 76                                 agricultural gypsum ii
# 77                                 agricultural gypsum ii
# 102                                agricultural gypsum ii
# 103                                agricultural gypsum ii
# 104                                agricultural gypsum ii
# 105                                agricultural gypsum ii
# 106                                agricultural gypsum ii
# 107                                agricultural gypsum ii
# ...                                                   ...
# 448920    enmotion high frequency use foam hand sanitizer
# 448921    enmotion high frequency use foam hand sanitizer
# 448922    enmotion high frequency use foam hand sanitizer
# 448923    enmotion high frequency use foam hand sanitizer
# 448968    enmotion high frequency use foam hand sanitizer
# 448969    enmotion high frequency use foam hand sanitizer
# 448970    enmotion high frequency use foam hand sanitizer
# 448971    enmotion high frequency use foam hand sanitizer
# 449004    enmotion high frequency use foam hand sanitizer
# 449005    enmotion high frequency use foam hand sanitizer
# 449006    enmotion high frequency use foam hand sanitizer
# 449007    enmotion high frequency use foam hand sanitizer
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133            georgia-pacific industrial hand cleaner
# 449136            georgia-pacific industrial hand cleaner
# 449141            georgia-pacific industrial hand cleaner
# 449148            georgia-pacific industrial hand cleaner
# 449157            georgia-pacific industrial hand cleaner
# 449168            georgia-pacific industrial hand cleaner
# 449181            georgia-pacific industrial hand cleaner
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
#                                              Product_List
# 0                                             gypsum rock
# 1                                           ground gypsum
# 2                                         granular gypsum
# 3                                              terra alba
# 4                      bumper harvest agricultural gypsum
# 5                                             landplaster
# 18                                            gypsum rock
# 19                                          ground gypsum
# 20                                        granular gypsum
# 21                                             terra alba
# 22                     bumper harvest agricultural gypsum
# 23                                            landplaster
# 54                                            gypsum rock
# 55                                          ground gypsum
# 56                                        granular gypsum
# 57                                             terra alba
# 58                     bumper harvest agricultural gypsum
# 59                                            landplaster
# 72                                            gypsum rock
# 73                                          ground gypsum
# 74                                        granular gypsum
# 75                                             terra alba
# 76                     bumper harvest agricultural gypsum
# 77                                            landplaster
# 102                                           gypsum rock
# 103                                         ground gypsum
# 104                                       granular gypsum
# 105                                            terra alba
# 106                    bumper harvest agricultural gypsum
# 107                                           landplaster
# ...                                                   ...
# 448920  enmotion high frequency use foam hand sanitize...
# 448921  enmotion high frequency use foam hand sanitize...
# 448922                                             gp6173
# 448923  enmotion high frequency foam hand sanitizer wi...
# 448968  enmotion high frequency use foam hand sanitize...
# 448969  enmotion high frequency use foam hand sanitize...
# 448970                                             gp6173
# 448971  enmotion high frequency foam hand sanitizer wi...
# 449004  enmotion high frequency use foam hand sanitize...
# 449005  enmotion high frequency use foam hand sanitize...
# 449006                                             gp6173
# 449007  enmotion high frequency foam hand sanitizer wi...
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133  georgia-pacific industrial hand cleaner sku-44623
# 449136  georgia-pacific industrial hand cleaner sku-44623
# 449141  georgia-pacific industrial hand cleaner sku-44623
# 449148  georgia-pacific industrial hand cleaner sku-44623
# 449157  georgia-pacific industrial hand cleaner sku-44623
# 449168  georgia-pacific industrial hand cleaner sku-44623
# 449181  georgia-pacific industrial hand cleaner sku-44623
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
# [5994 rows x 6 columns]

# %%
second = first_pass[first_pass['Chemical_Name'].map(lambda x: len(x) < 65)]

# %%
second['Chemical_Name'].value_counts()
filters2 = [
    '(pounds)',
    'instability: 0',
    '4945',
    '(sdwa)',
    'handling or working with this product.',
    'issue date',
    'disclaimer',
    'to be reliable.',
    'physical hazard: 0',
    'united states & puerto rico',
    'revision informaiton',
    'other federal regulations',
    'assumes a reasonable use of the product.',
    'nfpa ratings',
    'us. california proposition 65',
    'country(s).',
    'us state regulations',
    '16. other information_',
    'not regulated.',
]

# %%
third = second[second['Chemical_Name'].map(lambda x: x not in filters2)]

# %%
third['Chemical_Name'].value_counts()
filters3 = [
    'revision information',
    '**** found in products in list e and f_ section 1 of this sds.',
    'listed as a lung carcinogen.',
    'canada',
    'further information',
    'flammability: 1',
    '(a))',
    'revision date', 
    'portland cement',
    '800.424.9300',
    'precautionary statement',
    'regulations.',
    'hazard statement',
    'prevention'
]

# %%
fourth = third[third['Chemical_Name'].map(lambda x: x not in filters3)]

# %%
fourth['Chemical_Name'].value_counts()

filters4 = [
    'chemtrec - emergency :',
    'disposal',
    'united states',
    'response',
    'atlanta_ ga 30303',
    'georgia-pacific wood products llc',
    'storage',
    '133 peachtree street_ ne',
    'quantity',
    'chemical',
    'lower value', 
    'ecological information: ecotoxicity',
    'us'
]

# %%
fifth = fourth[fourth['Chemical_Name'].map(lambda x: x not in filters4)]

# %%
fifth['Chemical_Name'].value_counts()
# Out:
# crystalline silica (quartz)                              112
# calcium sulfate dihydrate                                 76
# hemihydrate                                               75
# calcium sulfate                                           75
# continuous filament glass                                 74
# wood/wood dust                                            70
# material name: 42a plasters                               59
# crystalline silica (quartz)*                              57
# formaldehyde                                              38
# wood/wood dust (cas not assigned)                         37
# fibers***                                                 37
# vermiculite****                                           37
# boric acid**                                              37
# polymeric mdi (pmdi)                                      34
# fragrance*                                                30
# ethyl alcohol                                             27
# cellulose                                                 25
# sara 313 (tri reporting)                                  24
# sara 311/312 hazardous                                    24
# gypsum (calcium sulfate)                                  23
# formaldehyde (cas 50-00-0)                                23
# glycerin                                                  23
# isocyanate (mdi)                                          22
# cocamidopropyl betaine                                    20
# methylene bisphenol                                       20
# vermiculite**                                             19
# (quartz) which is listed as a lung carcinogen.            19
# fiber                                                     19
# fibers                                                    18
# 10 of the sds).                                           18
#                                                         ...
# *ethanolamine (cas 141-43-5)                               1
# material name: copper azole pressure treated wood          1
# propiconazole (cas 60207-90-1)                             1
# 4778                                                       1
# potassium salts                                            1
# 14808-60-7)                                                1
# physical & chemical properties: multiple properties        1
# crystalline silica (quartz) (cas                           1
# 48252                                                      1
# 4_7-methano-1h-indenol_                                    1
# 5060                                                       1
# formaldehyde-naphthalene                                   1
# 8-hexamethyl-                                              1
# material name: georgia-pacific gel hand sanitizer          1
# 5530                                                       1
# polyurethane beads                                         1
# sulfonic acid polymer                                      1
# terpene-free                                               1
# crystalline silica (quartz) (cas 14808-60-7)               1
# cyclopenta[g]-2-benzopyra                                  1
# 5300                                                       1
# amyl salicylate                                            1
# material name: pacific garden head & body shampoo          1
# composition / information on ingredients: ingredients      1
# ammonia (cas 7664-41-7)                                    1
# 3a_4_5_6_7_7a-hexahydro-_                                  1
# 4123                                                       1
# hazreg data: international inventories                     1
# copper compounds (cas proprietary)                         1
# propionate                                                 1
# Name: Chemical_Name, Length: 309, dtype: int64

# %%
fifth['CAS_Number'].value_counts
sixth = fifth[fifth['CAS_Number'].map(lambda x: 'version' not in str(x))]

# %%
sixth
# Out:
#                       CAS_Number                Chemical_Name  \
# 0                     10101-41-4     gypsum (calcium sulfate)
# 1                     10101-41-4     gypsum (calcium sulfate)
# 2                     10101-41-4     gypsum (calcium sulfate)
# 3                     10101-41-4     gypsum (calcium sulfate)
# 4                     10101-41-4     gypsum (calcium sulfate)
# 5                     10101-41-4     gypsum (calcium sulfate)
# 18                    14808-60-7  crystalline silica (quartz)
# 19                    14808-60-7  crystalline silica (quartz)
# 20                    14808-60-7  crystalline silica (quartz)
# 21                    14808-60-7  crystalline silica (quartz)
# 22                    14808-60-7  crystalline silica (quartz)
# 23                    14808-60-7  crystalline silica (quartz)
# 54                     7778-18-9     gypsum (calcium sulfate)
# 55                     7778-18-9     gypsum (calcium sulfate)
# 56                     7778-18-9     gypsum (calcium sulfate)
# 57                     7778-18-9     gypsum (calcium sulfate)
# 58                     7778-18-9     gypsum (calcium sulfate)
# 59                     7778-18-9     gypsum (calcium sulfate)
# 72                     1318-00-9                  vermiculite
# 73                     1318-00-9                  vermiculite
# 74                     1318-00-9                  vermiculite
# 75                     1318-00-9                  vermiculite
# 76                     1318-00-9                  vermiculite
# 77                     1318-00-9                  vermiculite
# 102                   65997-17-3    continuous filament glass
# 103                   65997-17-3    continuous filament glass
# 104                   65997-17-3    continuous filament glass
# 105                   65997-17-3    continuous filament glass
# 106                   65997-17-3    continuous filament glass
# 107                   65997-17-3    continuous filament glass
# ...                          ...                          ...
# 448908                   64-17-5                ethyl alcohol
# 448909                   64-17-5                ethyl alcohol
# 448910                   64-17-5                ethyl alcohol
# 448911                   64-17-5                ethyl alcohol
# 448920                   67-63-0            isopropyl alcohol
# 448921                   67-63-0            isopropyl alcohol
# 448922                   67-63-0            isopropyl alcohol
# 448923                   67-63-0            isopropyl alcohol
# 449004  21 cfr part 333.410 (a).     antiseptic drug products
# 449005  21 cfr part 333.410 (a).     antiseptic drug products
# 449006  21 cfr part 333.410 (a).     antiseptic drug products
# 449007  21 cfr part 333.410 (a).     antiseptic drug products
# 449052                 7732-18-5                        water
# 449055                26183-52-8                     deceth-6
# 449060                68603-38-3           amides_ c16-18 and
# 449067                                       c18-unsaturated_
# 449076                                  n_n-bis(hydroxyethyl)
# 449087                   56-81-5                     glycerin
# 449100                68606-94-0         oils_ orange_ sweet_
# 449115                                           terpene-free
# 449133                 7732-18-5                        water
# 449136                 9009-54-5           polyurethane beads
# 449141                61790-12-3                tall oil acid
# 449148                69011-36-5                  trideceth-6
# 449157                68603-38-3           amides_ c16-18 and
# 449168                                       c18-unsaturated_
# 449181                                  n_n-bis(hydroxyethyl)
# 449197                   56-81-5                     glycerin
# 449200                68585-34-2       sodium laureth sulfate
# 449205                61789-40-0       cocamidopropyl betaine
#
#                                 Manufacturer Percentage  \
# 0                 georgia-pacific gypsum llc        100
# 1                 georgia-pacific gypsum llc        100
# 2                 georgia-pacific gypsum llc        100
# 3                 georgia-pacific gypsum llc        100
# 4                 georgia-pacific gypsum llc        100
# 5                 georgia-pacific gypsum llc        100
# 18                georgia-pacific gypsum llc        0-1
# 19                georgia-pacific gypsum llc        0-1
# 20                georgia-pacific gypsum llc        0-1
# 21                georgia-pacific gypsum llc        0-1
# 22                georgia-pacific gypsum llc        0-1
# 23                georgia-pacific gypsum llc        0-1
# 54                georgia-pacific gypsum llc         95
# 55                georgia-pacific gypsum llc         95
# 56                georgia-pacific gypsum llc         95
# 57                georgia-pacific gypsum llc         95
# 58                georgia-pacific gypsum llc         95
# 59                georgia-pacific gypsum llc         95
# 72                georgia-pacific gypsum llc        0-5
# 73                georgia-pacific gypsum llc        0-5
# 74                georgia-pacific gypsum llc        0-5
# 75                georgia-pacific gypsum llc        0-5
# 76                georgia-pacific gypsum llc        0-5
# 77                georgia-pacific gypsum llc        0-5
# 102               georgia-pacific gypsum llc        0-1
# 103               georgia-pacific gypsum llc        0-1
# 104               georgia-pacific gypsum llc        0-1
# 105               georgia-pacific gypsum llc        0-1
# 106               georgia-pacific gypsum llc        0-1
# 107               georgia-pacific gypsum llc        0-1
# ...                                      ...        ...
# 448908                     manufactured for:      55-70
# 448909                     manufactured for:      55-70
# 448910                     manufactured for:      55-70
# 448911                     manufactured for:      55-70
# 448920                     manufactured for:        1-5
# 448921                     manufactured for:        1-5
# 448922                     manufactured for:        1-5
# 448923                     manufactured for:        1-5
# 449004                     manufactured for:
# 449005                     manufactured for:
# 449006                     manufactured for:
# 449007                     manufactured for:
# 449052  georgia-pacific consumer products lp   60 - 100
# 449055  georgia-pacific consumer products lp     5 - 10
# 449060  georgia-pacific consumer products lp        1-5
# 449067  georgia-pacific consumer products lp
# 449076  georgia-pacific consumer products lp
# 449087  georgia-pacific consumer products lp        1-5
# 449100  georgia-pacific consumer products lp    0.1 - 1
# 449115  georgia-pacific consumer products lp
# 449133  georgia-pacific consumer products lp    70 - 80
# 449136  georgia-pacific consumer products lp     5 - 10
# 449141  georgia-pacific consumer products lp     5 - 10
# 449148  georgia-pacific consumer products lp     5 - 10
# 449157  georgia-pacific consumer products lp        1-3
# 449168  georgia-pacific consumer products lp
# 449181  georgia-pacific consumer products lp
# 449197                     manufactured for:        1-5
# 449200                     manufactured for:        1-5
# 449205                     manufactured for:    0.1 - 1
#
#                                        Product_Identifier  \
# 0                              uncalcined gypsum products
# 1                              uncalcined gypsum products
# 2                              uncalcined gypsum products
# 3                              uncalcined gypsum products
# 4                              uncalcined gypsum products
# 5                              uncalcined gypsum products
# 18                             uncalcined gypsum products
# 19                             uncalcined gypsum products
# 20                             uncalcined gypsum products
# 21                             uncalcined gypsum products
# 22                             uncalcined gypsum products
# 23                             uncalcined gypsum products
# 54                                 agricultural gypsum ii
# 55                                 agricultural gypsum ii
# 56                                 agricultural gypsum ii
# 57                                 agricultural gypsum ii
# 58                                 agricultural gypsum ii
# 59                                 agricultural gypsum ii
# 72                                 agricultural gypsum ii
# 73                                 agricultural gypsum ii
# 74                                 agricultural gypsum ii
# 75                                 agricultural gypsum ii
# 76                                 agricultural gypsum ii
# 77                                 agricultural gypsum ii
# 102                                agricultural gypsum ii
# 103                                agricultural gypsum ii
# 104                                agricultural gypsum ii
# 105                                agricultural gypsum ii
# 106                                agricultural gypsum ii
# 107                                agricultural gypsum ii
# ...                                                   ...
# 448908    enmotion high frequency use foam hand sanitizer
# 448909    enmotion high frequency use foam hand sanitizer
# 448910    enmotion high frequency use foam hand sanitizer
# 448911    enmotion high frequency use foam hand sanitizer
# 448920    enmotion high frequency use foam hand sanitizer
# 448921    enmotion high frequency use foam hand sanitizer
# 448922    enmotion high frequency use foam hand sanitizer
# 448923    enmotion high frequency use foam hand sanitizer
# 449004    enmotion high frequency use foam hand sanitizer
# 449005    enmotion high frequency use foam hand sanitizer
# 449006    enmotion high frequency use foam hand sanitizer
# 449007    enmotion high frequency use foam hand sanitizer
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133            georgia-pacific industrial hand cleaner
# 449136            georgia-pacific industrial hand cleaner
# 449141            georgia-pacific industrial hand cleaner
# 449148            georgia-pacific industrial hand cleaner
# 449157            georgia-pacific industrial hand cleaner
# 449168            georgia-pacific industrial hand cleaner
# 449181            georgia-pacific industrial hand cleaner
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
#                                              Product_List
# 0                                             gypsum rock
# 1                                           ground gypsum
# 2                                         granular gypsum
# 3                                              terra alba
# 4                      bumper harvest agricultural gypsum
# 5                                             landplaster
# 18                                            gypsum rock
# 19                                          ground gypsum
# 20                                        granular gypsum
# 21                                             terra alba
# 22                     bumper harvest agricultural gypsum
# 23                                            landplaster
# 54                                            gypsum rock
# 55                                          ground gypsum
# 56                                        granular gypsum
# 57                                             terra alba
# 58                     bumper harvest agricultural gypsum
# 59                                            landplaster
# 72                                            gypsum rock
# 73                                          ground gypsum
# 74                                        granular gypsum
# 75                                             terra alba
# 76                     bumper harvest agricultural gypsum
# 77                                            landplaster
# 102                                           gypsum rock
# 103                                         ground gypsum
# 104                                       granular gypsum
# 105                                            terra alba
# 106                    bumper harvest agricultural gypsum
# 107                                           landplaster
# ...                                                   ...
# 448908  enmotion high frequency use foam hand sanitize...
# 448909  enmotion high frequency use foam hand sanitize...
# 448910                                             gp6173
# 448911  enmotion high frequency foam hand sanitizer wi...
# 448920  enmotion high frequency use foam hand sanitize...
# 448921  enmotion high frequency use foam hand sanitize...
# 448922                                             gp6173
# 448923  enmotion high frequency foam hand sanitizer wi...
# 449004  enmotion high frequency use foam hand sanitize...
# 449005  enmotion high frequency use foam hand sanitize...
# 449006                                             gp6173
# 449007  enmotion high frequency foam hand sanitizer wi...
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133  georgia-pacific industrial hand cleaner sku-44623
# 449136  georgia-pacific industrial hand cleaner sku-44623
# 449141  georgia-pacific industrial hand cleaner sku-44623
# 449148  georgia-pacific industrial hand cleaner sku-44623
# 449157  georgia-pacific industrial hand cleaner sku-44623
# 449168  georgia-pacific industrial hand cleaner sku-44623
# 449181  georgia-pacific industrial hand cleaner sku-44623
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
# [2502 rows x 6 columns]

# %%
seventh = sixth[sixth['Chemical_Name'].map(lambda x: 'material name:' not in str(x))]

# %%
seventh['Chemical_Name'].value_counts()
eighth = seventh[seventh['Chemical_Name'].map(lambda x: 'sara' not in str(x))]
eighth
# Out:
#                       CAS_Number                Chemical_Name  \
# 0                     10101-41-4     gypsum (calcium sulfate)
# 1                     10101-41-4     gypsum (calcium sulfate)
# 2                     10101-41-4     gypsum (calcium sulfate)
# 3                     10101-41-4     gypsum (calcium sulfate)
# 4                     10101-41-4     gypsum (calcium sulfate)
# 5                     10101-41-4     gypsum (calcium sulfate)
# 18                    14808-60-7  crystalline silica (quartz)
# 19                    14808-60-7  crystalline silica (quartz)
# 20                    14808-60-7  crystalline silica (quartz)
# 21                    14808-60-7  crystalline silica (quartz)
# 22                    14808-60-7  crystalline silica (quartz)
# 23                    14808-60-7  crystalline silica (quartz)
# 54                     7778-18-9     gypsum (calcium sulfate)
# 55                     7778-18-9     gypsum (calcium sulfate)
# 56                     7778-18-9     gypsum (calcium sulfate)
# 57                     7778-18-9     gypsum (calcium sulfate)
# 58                     7778-18-9     gypsum (calcium sulfate)
# 59                     7778-18-9     gypsum (calcium sulfate)
# 72                     1318-00-9                  vermiculite
# 73                     1318-00-9                  vermiculite
# 74                     1318-00-9                  vermiculite
# 75                     1318-00-9                  vermiculite
# 76                     1318-00-9                  vermiculite
# 77                     1318-00-9                  vermiculite
# 102                   65997-17-3    continuous filament glass
# 103                   65997-17-3    continuous filament glass
# 104                   65997-17-3    continuous filament glass
# 105                   65997-17-3    continuous filament glass
# 106                   65997-17-3    continuous filament glass
# 107                   65997-17-3    continuous filament glass
# ...                          ...                          ...
# 448908                   64-17-5                ethyl alcohol
# 448909                   64-17-5                ethyl alcohol
# 448910                   64-17-5                ethyl alcohol
# 448911                   64-17-5                ethyl alcohol
# 448920                   67-63-0            isopropyl alcohol
# 448921                   67-63-0            isopropyl alcohol
# 448922                   67-63-0            isopropyl alcohol
# 448923                   67-63-0            isopropyl alcohol
# 449004  21 cfr part 333.410 (a).     antiseptic drug products
# 449005  21 cfr part 333.410 (a).     antiseptic drug products
# 449006  21 cfr part 333.410 (a).     antiseptic drug products
# 449007  21 cfr part 333.410 (a).     antiseptic drug products
# 449052                 7732-18-5                        water
# 449055                26183-52-8                     deceth-6
# 449060                68603-38-3           amides_ c16-18 and
# 449067                                       c18-unsaturated_
# 449076                                  n_n-bis(hydroxyethyl)
# 449087                   56-81-5                     glycerin
# 449100                68606-94-0         oils_ orange_ sweet_
# 449115                                           terpene-free
# 449133                 7732-18-5                        water
# 449136                 9009-54-5           polyurethane beads
# 449141                61790-12-3                tall oil acid
# 449148                69011-36-5                  trideceth-6
# 449157                68603-38-3           amides_ c16-18 and
# 449168                                       c18-unsaturated_
# 449181                                  n_n-bis(hydroxyethyl)
# 449197                   56-81-5                     glycerin
# 449200                68585-34-2       sodium laureth sulfate
# 449205                61789-40-0       cocamidopropyl betaine
#
#                                 Manufacturer Percentage  \
# 0                 georgia-pacific gypsum llc        100
# 1                 georgia-pacific gypsum llc        100
# 2                 georgia-pacific gypsum llc        100
# 3                 georgia-pacific gypsum llc        100
# 4                 georgia-pacific gypsum llc        100
# 5                 georgia-pacific gypsum llc        100
# 18                georgia-pacific gypsum llc        0-1
# 19                georgia-pacific gypsum llc        0-1
# 20                georgia-pacific gypsum llc        0-1
# 21                georgia-pacific gypsum llc        0-1
# 22                georgia-pacific gypsum llc        0-1
# 23                georgia-pacific gypsum llc        0-1
# 54                georgia-pacific gypsum llc         95
# 55                georgia-pacific gypsum llc         95
# 56                georgia-pacific gypsum llc         95
# 57                georgia-pacific gypsum llc         95
# 58                georgia-pacific gypsum llc         95
# 59                georgia-pacific gypsum llc         95
# 72                georgia-pacific gypsum llc        0-5
# 73                georgia-pacific gypsum llc        0-5
# 74                georgia-pacific gypsum llc        0-5
# 75                georgia-pacific gypsum llc        0-5
# 76                georgia-pacific gypsum llc        0-5
# 77                georgia-pacific gypsum llc        0-5
# 102               georgia-pacific gypsum llc        0-1
# 103               georgia-pacific gypsum llc        0-1
# 104               georgia-pacific gypsum llc        0-1
# 105               georgia-pacific gypsum llc        0-1
# 106               georgia-pacific gypsum llc        0-1
# 107               georgia-pacific gypsum llc        0-1
# ...                                      ...        ...
# 448908                     manufactured for:      55-70
# 448909                     manufactured for:      55-70
# 448910                     manufactured for:      55-70
# 448911                     manufactured for:      55-70
# 448920                     manufactured for:        1-5
# 448921                     manufactured for:        1-5
# 448922                     manufactured for:        1-5
# 448923                     manufactured for:        1-5
# 449004                     manufactured for:
# 449005                     manufactured for:
# 449006                     manufactured for:
# 449007                     manufactured for:
# 449052  georgia-pacific consumer products lp   60 - 100
# 449055  georgia-pacific consumer products lp     5 - 10
# 449060  georgia-pacific consumer products lp        1-5
# 449067  georgia-pacific consumer products lp
# 449076  georgia-pacific consumer products lp
# 449087  georgia-pacific consumer products lp        1-5
# 449100  georgia-pacific consumer products lp    0.1 - 1
# 449115  georgia-pacific consumer products lp
# 449133  georgia-pacific consumer products lp    70 - 80
# 449136  georgia-pacific consumer products lp     5 - 10
# 449141  georgia-pacific consumer products lp     5 - 10
# 449148  georgia-pacific consumer products lp     5 - 10
# 449157  georgia-pacific consumer products lp        1-3
# 449168  georgia-pacific consumer products lp
# 449181  georgia-pacific consumer products lp
# 449197                     manufactured for:        1-5
# 449200                     manufactured for:        1-5
# 449205                     manufactured for:    0.1 - 1
#
#                                        Product_Identifier  \
# 0                              uncalcined gypsum products
# 1                              uncalcined gypsum products
# 2                              uncalcined gypsum products
# 3                              uncalcined gypsum products
# 4                              uncalcined gypsum products
# 5                              uncalcined gypsum products
# 18                             uncalcined gypsum products
# 19                             uncalcined gypsum products
# 20                             uncalcined gypsum products
# 21                             uncalcined gypsum products
# 22                             uncalcined gypsum products
# 23                             uncalcined gypsum products
# 54                                 agricultural gypsum ii
# 55                                 agricultural gypsum ii
# 56                                 agricultural gypsum ii
# 57                                 agricultural gypsum ii
# 58                                 agricultural gypsum ii
# 59                                 agricultural gypsum ii
# 72                                 agricultural gypsum ii
# 73                                 agricultural gypsum ii
# 74                                 agricultural gypsum ii
# 75                                 agricultural gypsum ii
# 76                                 agricultural gypsum ii
# 77                                 agricultural gypsum ii
# 102                                agricultural gypsum ii
# 103                                agricultural gypsum ii
# 104                                agricultural gypsum ii
# 105                                agricultural gypsum ii
# 106                                agricultural gypsum ii
# 107                                agricultural gypsum ii
# ...                                                   ...
# 448908    enmotion high frequency use foam hand sanitizer
# 448909    enmotion high frequency use foam hand sanitizer
# 448910    enmotion high frequency use foam hand sanitizer
# 448911    enmotion high frequency use foam hand sanitizer
# 448920    enmotion high frequency use foam hand sanitizer
# 448921    enmotion high frequency use foam hand sanitizer
# 448922    enmotion high frequency use foam hand sanitizer
# 448923    enmotion high frequency use foam hand sanitizer
# 449004    enmotion high frequency use foam hand sanitizer
# 449005    enmotion high frequency use foam hand sanitizer
# 449006    enmotion high frequency use foam hand sanitizer
# 449007    enmotion high frequency use foam hand sanitizer
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133            georgia-pacific industrial hand cleaner
# 449136            georgia-pacific industrial hand cleaner
# 449141            georgia-pacific industrial hand cleaner
# 449148            georgia-pacific industrial hand cleaner
# 449157            georgia-pacific industrial hand cleaner
# 449168            georgia-pacific industrial hand cleaner
# 449181            georgia-pacific industrial hand cleaner
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
#                                              Product_List
# 0                                             gypsum rock
# 1                                           ground gypsum
# 2                                         granular gypsum
# 3                                              terra alba
# 4                      bumper harvest agricultural gypsum
# 5                                             landplaster
# 18                                            gypsum rock
# 19                                          ground gypsum
# 20                                        granular gypsum
# 21                                             terra alba
# 22                     bumper harvest agricultural gypsum
# 23                                            landplaster
# 54                                            gypsum rock
# 55                                          ground gypsum
# 56                                        granular gypsum
# 57                                             terra alba
# 58                     bumper harvest agricultural gypsum
# 59                                            landplaster
# 72                                            gypsum rock
# 73                                          ground gypsum
# 74                                        granular gypsum
# 75                                             terra alba
# 76                     bumper harvest agricultural gypsum
# 77                                            landplaster
# 102                                           gypsum rock
# 103                                         ground gypsum
# 104                                       granular gypsum
# 105                                            terra alba
# 106                    bumper harvest agricultural gypsum
# 107                                           landplaster
# ...                                                   ...
# 448908  enmotion high frequency use foam hand sanitize...
# 448909  enmotion high frequency use foam hand sanitize...
# 448910                                             gp6173
# 448911  enmotion high frequency foam hand sanitizer wi...
# 448920  enmotion high frequency use foam hand sanitize...
# 448921  enmotion high frequency use foam hand sanitize...
# 448922                                             gp6173
# 448923  enmotion high frequency foam hand sanitizer wi...
# 449004  enmotion high frequency use foam hand sanitize...
# 449005  enmotion high frequency use foam hand sanitize...
# 449006                                             gp6173
# 449007  enmotion high frequency foam hand sanitizer wi...
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133  georgia-pacific industrial hand cleaner sku-44623
# 449136  georgia-pacific industrial hand cleaner sku-44623
# 449141  georgia-pacific industrial hand cleaner sku-44623
# 449148  georgia-pacific industrial hand cleaner sku-44623
# 449157  georgia-pacific industrial hand cleaner sku-44623
# 449168  georgia-pacific industrial hand cleaner sku-44623
# 449181  georgia-pacific industrial hand cleaner sku-44623
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
# [2326 rows x 6 columns]

# %%
ninth = eighth[eighth['CAS_Number'].map(lambda x: 'see section 8 for exposure information.' not in str(x))]

# %%
ninth[ 'CAS_Number'].value_counts()
tenth = ninth[ninth['CAS_Number'].map(lambda x: 'listed:' not in str(x))]

# %%
tenth
# Out:
#                       CAS_Number                Chemical_Name  \
# 0                     10101-41-4     gypsum (calcium sulfate)
# 1                     10101-41-4     gypsum (calcium sulfate)
# 2                     10101-41-4     gypsum (calcium sulfate)
# 3                     10101-41-4     gypsum (calcium sulfate)
# 4                     10101-41-4     gypsum (calcium sulfate)
# 5                     10101-41-4     gypsum (calcium sulfate)
# 18                    14808-60-7  crystalline silica (quartz)
# 19                    14808-60-7  crystalline silica (quartz)
# 20                    14808-60-7  crystalline silica (quartz)
# 21                    14808-60-7  crystalline silica (quartz)
# 22                    14808-60-7  crystalline silica (quartz)
# 23                    14808-60-7  crystalline silica (quartz)
# 54                     7778-18-9     gypsum (calcium sulfate)
# 55                     7778-18-9     gypsum (calcium sulfate)
# 56                     7778-18-9     gypsum (calcium sulfate)
# 57                     7778-18-9     gypsum (calcium sulfate)
# 58                     7778-18-9     gypsum (calcium sulfate)
# 59                     7778-18-9     gypsum (calcium sulfate)
# 72                     1318-00-9                  vermiculite
# 73                     1318-00-9                  vermiculite
# 74                     1318-00-9                  vermiculite
# 75                     1318-00-9                  vermiculite
# 76                     1318-00-9                  vermiculite
# 77                     1318-00-9                  vermiculite
# 102                   65997-17-3    continuous filament glass
# 103                   65997-17-3    continuous filament glass
# 104                   65997-17-3    continuous filament glass
# 105                   65997-17-3    continuous filament glass
# 106                   65997-17-3    continuous filament glass
# 107                   65997-17-3    continuous filament glass
# ...                          ...                          ...
# 448908                   64-17-5                ethyl alcohol
# 448909                   64-17-5                ethyl alcohol
# 448910                   64-17-5                ethyl alcohol
# 448911                   64-17-5                ethyl alcohol
# 448920                   67-63-0            isopropyl alcohol
# 448921                   67-63-0            isopropyl alcohol
# 448922                   67-63-0            isopropyl alcohol
# 448923                   67-63-0            isopropyl alcohol
# 449004  21 cfr part 333.410 (a).     antiseptic drug products
# 449005  21 cfr part 333.410 (a).     antiseptic drug products
# 449006  21 cfr part 333.410 (a).     antiseptic drug products
# 449007  21 cfr part 333.410 (a).     antiseptic drug products
# 449052                 7732-18-5                        water
# 449055                26183-52-8                     deceth-6
# 449060                68603-38-3           amides_ c16-18 and
# 449067                                       c18-unsaturated_
# 449076                                  n_n-bis(hydroxyethyl)
# 449087                   56-81-5                     glycerin
# 449100                68606-94-0         oils_ orange_ sweet_
# 449115                                           terpene-free
# 449133                 7732-18-5                        water
# 449136                 9009-54-5           polyurethane beads
# 449141                61790-12-3                tall oil acid
# 449148                69011-36-5                  trideceth-6
# 449157                68603-38-3           amides_ c16-18 and
# 449168                                       c18-unsaturated_
# 449181                                  n_n-bis(hydroxyethyl)
# 449197                   56-81-5                     glycerin
# 449200                68585-34-2       sodium laureth sulfate
# 449205                61789-40-0       cocamidopropyl betaine
#
#                                 Manufacturer Percentage  \
# 0                 georgia-pacific gypsum llc        100
# 1                 georgia-pacific gypsum llc        100
# 2                 georgia-pacific gypsum llc        100
# 3                 georgia-pacific gypsum llc        100
# 4                 georgia-pacific gypsum llc        100
# 5                 georgia-pacific gypsum llc        100
# 18                georgia-pacific gypsum llc        0-1
# 19                georgia-pacific gypsum llc        0-1
# 20                georgia-pacific gypsum llc        0-1
# 21                georgia-pacific gypsum llc        0-1
# 22                georgia-pacific gypsum llc        0-1
# 23                georgia-pacific gypsum llc        0-1
# 54                georgia-pacific gypsum llc         95
# 55                georgia-pacific gypsum llc         95
# 56                georgia-pacific gypsum llc         95
# 57                georgia-pacific gypsum llc         95
# 58                georgia-pacific gypsum llc         95
# 59                georgia-pacific gypsum llc         95
# 72                georgia-pacific gypsum llc        0-5
# 73                georgia-pacific gypsum llc        0-5
# 74                georgia-pacific gypsum llc        0-5
# 75                georgia-pacific gypsum llc        0-5
# 76                georgia-pacific gypsum llc        0-5
# 77                georgia-pacific gypsum llc        0-5
# 102               georgia-pacific gypsum llc        0-1
# 103               georgia-pacific gypsum llc        0-1
# 104               georgia-pacific gypsum llc        0-1
# 105               georgia-pacific gypsum llc        0-1
# 106               georgia-pacific gypsum llc        0-1
# 107               georgia-pacific gypsum llc        0-1
# ...                                      ...        ...
# 448908                     manufactured for:      55-70
# 448909                     manufactured for:      55-70
# 448910                     manufactured for:      55-70
# 448911                     manufactured for:      55-70
# 448920                     manufactured for:        1-5
# 448921                     manufactured for:        1-5
# 448922                     manufactured for:        1-5
# 448923                     manufactured for:        1-5
# 449004                     manufactured for:
# 449005                     manufactured for:
# 449006                     manufactured for:
# 449007                     manufactured for:
# 449052  georgia-pacific consumer products lp   60 - 100
# 449055  georgia-pacific consumer products lp     5 - 10
# 449060  georgia-pacific consumer products lp        1-5
# 449067  georgia-pacific consumer products lp
# 449076  georgia-pacific consumer products lp
# 449087  georgia-pacific consumer products lp        1-5
# 449100  georgia-pacific consumer products lp    0.1 - 1
# 449115  georgia-pacific consumer products lp
# 449133  georgia-pacific consumer products lp    70 - 80
# 449136  georgia-pacific consumer products lp     5 - 10
# 449141  georgia-pacific consumer products lp     5 - 10
# 449148  georgia-pacific consumer products lp     5 - 10
# 449157  georgia-pacific consumer products lp        1-3
# 449168  georgia-pacific consumer products lp
# 449181  georgia-pacific consumer products lp
# 449197                     manufactured for:        1-5
# 449200                     manufactured for:        1-5
# 449205                     manufactured for:    0.1 - 1
#
#                                        Product_Identifier  \
# 0                              uncalcined gypsum products
# 1                              uncalcined gypsum products
# 2                              uncalcined gypsum products
# 3                              uncalcined gypsum products
# 4                              uncalcined gypsum products
# 5                              uncalcined gypsum products
# 18                             uncalcined gypsum products
# 19                             uncalcined gypsum products
# 20                             uncalcined gypsum products
# 21                             uncalcined gypsum products
# 22                             uncalcined gypsum products
# 23                             uncalcined gypsum products
# 54                                 agricultural gypsum ii
# 55                                 agricultural gypsum ii
# 56                                 agricultural gypsum ii
# 57                                 agricultural gypsum ii
# 58                                 agricultural gypsum ii
# 59                                 agricultural gypsum ii
# 72                                 agricultural gypsum ii
# 73                                 agricultural gypsum ii
# 74                                 agricultural gypsum ii
# 75                                 agricultural gypsum ii
# 76                                 agricultural gypsum ii
# 77                                 agricultural gypsum ii
# 102                                agricultural gypsum ii
# 103                                agricultural gypsum ii
# 104                                agricultural gypsum ii
# 105                                agricultural gypsum ii
# 106                                agricultural gypsum ii
# 107                                agricultural gypsum ii
# ...                                                   ...
# 448908    enmotion high frequency use foam hand sanitizer
# 448909    enmotion high frequency use foam hand sanitizer
# 448910    enmotion high frequency use foam hand sanitizer
# 448911    enmotion high frequency use foam hand sanitizer
# 448920    enmotion high frequency use foam hand sanitizer
# 448921    enmotion high frequency use foam hand sanitizer
# 448922    enmotion high frequency use foam hand sanitizer
# 448923    enmotion high frequency use foam hand sanitizer
# 449004    enmotion high frequency use foam hand sanitizer
# 449005    enmotion high frequency use foam hand sanitizer
# 449006    enmotion high frequency use foam hand sanitizer
# 449007    enmotion high frequency use foam hand sanitizer
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133            georgia-pacific industrial hand cleaner
# 449136            georgia-pacific industrial hand cleaner
# 449141            georgia-pacific industrial hand cleaner
# 449148            georgia-pacific industrial hand cleaner
# 449157            georgia-pacific industrial hand cleaner
# 449168            georgia-pacific industrial hand cleaner
# 449181            georgia-pacific industrial hand cleaner
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
#                                              Product_List
# 0                                             gypsum rock
# 1                                           ground gypsum
# 2                                         granular gypsum
# 3                                              terra alba
# 4                      bumper harvest agricultural gypsum
# 5                                             landplaster
# 18                                            gypsum rock
# 19                                          ground gypsum
# 20                                        granular gypsum
# 21                                             terra alba
# 22                     bumper harvest agricultural gypsum
# 23                                            landplaster
# 54                                            gypsum rock
# 55                                          ground gypsum
# 56                                        granular gypsum
# 57                                             terra alba
# 58                     bumper harvest agricultural gypsum
# 59                                            landplaster
# 72                                            gypsum rock
# 73                                          ground gypsum
# 74                                        granular gypsum
# 75                                             terra alba
# 76                     bumper harvest agricultural gypsum
# 77                                            landplaster
# 102                                           gypsum rock
# 103                                         ground gypsum
# 104                                       granular gypsum
# 105                                            terra alba
# 106                    bumper harvest agricultural gypsum
# 107                                           landplaster
# ...                                                   ...
# 448908  enmotion high frequency use foam hand sanitize...
# 448909  enmotion high frequency use foam hand sanitize...
# 448910                                             gp6173
# 448911  enmotion high frequency foam hand sanitizer wi...
# 448920  enmotion high frequency use foam hand sanitize...
# 448921  enmotion high frequency use foam hand sanitize...
# 448922                                             gp6173
# 448923  enmotion high frequency foam hand sanitizer wi...
# 449004  enmotion high frequency use foam hand sanitize...
# 449005  enmotion high frequency use foam hand sanitize...
# 449006                                             gp6173
# 449007  enmotion high frequency foam hand sanitizer wi...
# 449052  georgia-pacific heavy duty industrial hand cle...
# 449055  georgia-pacific heavy duty industrial hand cle...
# 449060  georgia-pacific heavy duty industrial hand cle...
# 449067  georgia-pacific heavy duty industrial hand cle...
# 449076  georgia-pacific heavy duty industrial hand cle...
# 449087  georgia-pacific heavy duty industrial hand cle...
# 449100  georgia-pacific heavy duty industrial hand cle...
# 449115  georgia-pacific heavy duty industrial hand cle...
# 449133  georgia-pacific industrial hand cleaner sku-44623
# 449136  georgia-pacific industrial hand cleaner sku-44623
# 449141  georgia-pacific industrial hand cleaner sku-44623
# 449148  georgia-pacific industrial hand cleaner sku-44623
# 449157  georgia-pacific industrial hand cleaner sku-44623
# 449168  georgia-pacific industrial hand cleaner sku-44623
# 449181  georgia-pacific industrial hand cleaner sku-44623
# 449197  enmotion general purpose foam soap_ dye-free f...
# 449200  enmotion general purpose foam soap_ dye-free f...
# 449205  enmotion general purpose foam soap_ dye-free f...
#
# [2260 rows x 6 columns]

# %%
#create function to export dataframe to excel file
import os
import pandas as pd


def checkfile(file_name):
    """
    Usage:
    ------
    checkfile(file_name)

    Description:
    ------------
    Function to check if a file name exists in the current working
    directory and rename the new file, rather than overwrite the old file
    with new data.

    Parameters:
    -----------
    file_name : string, database name tag in .my.cnf file (default=None)
    out       : string, a unique file name based on the provided file_name;
                uniqueness is insured by incrementing a number appended to the
                file by 1
    """
    cwd = os.getcwd()
    cwf = os.path.join(cwd,file_name)
    if not os.path.exists(cwf):
        return cwf
    root, ext = os.path.splitext(os.path.expanduser(cwf))
    dir = os.path.dirname(root)
    fname = os.path.basename(root)
    candidate = fname+ext
    index = 1
    ls = set(os.listdir(dir))
    while candidate in ls:
        candidate = "{}_{}{}".format(fname,index,ext)
        index += 1
    return os.path.join(dir,candidate)

def to_excel(df,xlfile,sheet_name='Sheet 1',cas_col='casrn',index=False,filecheck=False,encoding=None):
    """
    Usage:
    ------
    to_excel(df,xlfile)

    Description:
    ------------
    Writes Pandas dataframe to MS Excel file. This differs from Pandas' own
    to_excel function in that it will find the 'casrn' column and write it to
    the file as a string instead of a number, thus preventing some CASRNs to be
    autoformatted to strings.

    Parameters:
    -----------
    df              pandas.DataFrame, object to write to an MS Excel file
    xlfile          string, name of MS Excel file to generate
    sheet_name      string, name of MS Excel sheet the dataframe will be written to
    cas_col         string, name of the column in the dataframe containing CASRNs (default:'casrn')
    index           boolean, default True write row names (index)
    checkfile       check if a file by the same name already exists in the path

    """
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    if cas_col not in df.columns.tolist():
        print("Error! 'casrn' column not in dataframe. Use Pandas' to_excel function.")
        return

    cas_col = alphabet[df.columns.get_loc(cas_col)].upper()
    if filecheck:
        writer = pd.ExcelWriter(checkfile(xlfile),engine="xlsxwriter")
    else:
        writer = pd.ExcelWriter(xlfile,engine="xlsxwriter")
    df.to_excel(writer,sheet_name=sheet_name,index=index,encoding=encoding)
    workbook = writer.book
    worksheet = writer.sheets[sheet_name]
    format1 = workbook.add_format({"bold":False,"font_color":"black"})
    worksheet.set_column(cas_col+':'+cas_col,12,format1)
    writer.save()
    return

# %%
to_excel(df = tenth, xlfile = 'Georgia_Pacific_Scraped_Data.xls' , cas_col = 'CAS_Number')
